# %%
import numpy as np  
import matplotlib.pyplot as plt  
import pandas as pd  
from apyori import apriori

store_data = pd.read_csv('C:\\Users\\Pooja Suvarna\\Desktop\\made.csv', header=None) 
store_data.head()
# Out:
#           0            1            2            3            4     \
# 0    VIOLATION  MISDEMEANOR    VIOLATION  MISDEMEANOR    VIOLATION
# 1  MISDEMEANOR    VIOLATION  MISDEMEANOR       FELONY       FELONY
# 2  MISDEMEANOR       FELONY  MISDEMEANOR       FELONY  MISDEMEANOR
# 3    VIOLATION  MISDEMEANOR       FELONY       FELONY  MISDEMEANOR
# 4  MISDEMEANOR  MISDEMEANOR       FELONY  MISDEMEANOR       FELONY
#
#           5            6            7          8            9       ...      \
# 0  MISDEMEANOR  MISDEMEANOR  MISDEMEANOR  VIOLATION       FELONY    ...
# 1  MISDEMEANOR  MISDEMEANOR  MISDEMEANOR     FELONY  MISDEMEANOR    ...
# 2  MISDEMEANOR       FELONY       FELONY     FELONY    VIOLATION    ...
# 3  MISDEMEANOR  MISDEMEANOR    VIOLATION  VIOLATION  MISDEMEANOR    ...
# 4  MISDEMEANOR       FELONY  MISDEMEANOR     FELONY       FELONY    ...
#
#           5089         5090       5091    5092         5093         5094  \
# ...

# %%
records = []  
for i in range(0, 4):  
    records.append([str(store_data.values[i,j]) for j in range(0, 5098)])

# %%
association_rules = apriori(records, min_support=0.5, min_confidence=0.3, min_lift=0, min_length=0)  
association_results = list(association_rules)

# %%
association_results
# Out:
# [RelationRecord(items=frozenset({'FELONY'}), support=1.0, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'FELONY'}), confidence=1.0, lift=1.0)]),
#  RelationRecord(items=frozenset({'MISDEMEANOR'}), support=1.0, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'MISDEMEANOR'}), confidence=1.0, lift=1.0)]),
#  RelationRecord(items=frozenset({'VIOLATION'}), support=1.0, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'VIOLATION'}), confidence=1.0, lift=1.0)]),
#  RelationRecord(items=frozenset({'nan'}), support=0.75, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'nan'}), confidence=0.75, lift=1.0)]),
# ...

# %%
for item in association_results:

    # first index of the inner list
    # Contains base item and add item
    pair = item[0] 
    items = [x for x in pair]
    lenght = len(items)
    if lenght==2:
        print("Rule: " + items[0] + " -> " + items[1])

        #second index of the inner list
        print("Support: " + str(item[1]))

        #third index of the list located at 0th
        #of the third index of the inner list

        print("Confidence: " + str(item[2][0][2]))
        print("Lift: " + str(item[2][0][3]))
        print("=====================================")
# Out:
# Rule: MISDEMEANOR -> FELONY
# Support: 1.0
# Confidence: 1.0
# Lift: 1.0
# ...
# Rule: VIOLATION -> FELONY
# Support: 1.0
# Confidence: 1.0
# Lift: 1.0
# ...
# Rule: nan -> FELONY
# Support: 0.75
# Confidence: 0.75
# Lift: 1.0
# ...
# Rule: MISDEMEANOR -> VIOLATION
# Support: 1.0
# Confidence: 1.0
# Lift: 1.0
# ...
# Rule: MISDEMEANOR -> nan
# Support: 0.75
# Confidence: 0.75
# Lift: 1.0
# ...
# Rule: VIOLATION -> nan
# Support: 0.75
# Confidence: 0.75
# Lift: 1.0
# ...
